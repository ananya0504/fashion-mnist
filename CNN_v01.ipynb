# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# Link  https://keras.io/datasets/#fashion-mnist-database-of-fashion-articles
#
# Dataset of 60,000 28x28 grayscale images of 10 fashion categories, along with a test set of 10,000 images. The class labels are:
#
# | Label |	Description |
# --- | --- |
# | 0	| T-shirt/top
# | 1	| Trouser
# | 2	| Pullover
# | 3	| Dress
# | 4	| Coat
# | 5	| Sandal
# | 6	| Shirt
# | 7	| Sneaker
# | 8	| Bag
# | 9	| Ankle boot
#
# ![](image.png "Title")
#
# ### Usage:
# from keras.datasets import fashion_mnist
#
# > (x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
#
# Returns:
# 2 tuples:
# 1. x_train, x_test: uint8 array of grayscale image data with shape (num_samples, 28, 28).
# 2. y_train, y_test: uint8 array of labels (integers in range 0-9) with shape (num_samples,).

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist.load_data()

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %% [markdown]
# ### Data Reshape

# %%
X_train_full = X_train_full.reshape((60000, 28, 28, 1))
X_test = X_test.reshape((10000, 28, 28, 1))

# %% [markdown]
# ### Data normalization
# We then normalize the data dimensions so that they are of approximately the same scale.

# %%
X_train_n = X_train_full / 255.
X_test_n = X_test / 255.

# %% [markdown]
# ### Split the data into train/validation/test datasets
# In the earlier step of importing the date, we had 60,000 datasets for training and 10,000 test datasets. Now we further split the training data into train/validation. Here is how each type of dateset is used in deep learning:
#
# * __Training data__ — used for training the model
# * __Validation data__ — used for tuning the hyperparameters and evaluate the models
# * __Test data__ — used to test the model after the model has gone through initial vetting by the validation set.

# %%
X_valid, X_train = X_train_n[:5000], X_train_n[5000:]
y_valid, y_train = y_train_full[:5000], y_train_full[5000:]
X_test = X_test_n

# %% [markdown]
# ### Create the model architecture

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ### Architecture
#
# ![](cnn.png "Title")

# %% [markdown]
# We are going to use 32 different filters in the convolutional layer, hence size is 26x26x32

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides=1, padding='valid', activation='relu', input_shape=(28, 28, 1)))
model.add(keras.layers.MaxPooling2D((2, 2)))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# dense (Dense)                (None, 300)               1622700
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 1,654,130
# Trainable params: 1,654,130
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Here we see that we need to train 1622700 parameters, had we not used the max pooling layer, we would have to train 4000000 parameters. It has signinficantly reduced the number of parameters for us.

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %%
model_history = model.fit(X_train, y_train, epochs=30,batch_size= 64,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/30
# 860/860 [==============================] - 30s 34ms/step - loss: 0.8767 - accuracy: 0.6992 - val_loss: 0.7489 - val_accuracy: 0.7368
# Epoch 2/30
# 860/860 [==============================] - 25s 30ms/step - loss: 0.5386 - accuracy: 0.8051 - val_loss: 0.4915 - val_accuracy: 0.8186
# Epoch 3/30
# 860/860 [==============================] - 24s 28ms/step - loss: 0.4805 - accuracy: 0.8259 - val_loss: 0.9241 - val_accuracy: 0.7080
# Epoch 4/30
# 860/860 [==============================] - 30s 34ms/step - loss: 0.4432 - accuracy: 0.8421 - val_loss: 0.4148 - val_accuracy: 0.8562
# Epoch 5/30
# 860/860 [==============================] - 29s 33ms/step - loss: 0.4192 - accuracy: 0.8504 - val_loss: 0.4368 - val_accuracy: 0.8466
# Epoch 6/30
# 860/860 [==============================] - 31s 36ms/step - loss: 0.3953 - accuracy: 0.8587 - val_loss: 0.3770 - val_accuracy: 0.8698
# Epoch 7/30
# 860/860 [==============================] - 30s 35ms/step - loss: 0.3776 - accuracy: 0.8656 - val_loss: 0.4044 - val_accuracy: 0.8570
# Epoch 8/30
# 860/860 [==============================] - 35s 41ms/step - loss: 0.3627 - accuracy: 0.8693 - val_loss: 0.5158 - val_accuracy: 0.8086
# Epoch 9/30
# 860/860 [==============================] - 32s 38ms/step - loss: 0.3485 - accuracy: 0.8745 - val_loss: 0.3708 - val_accuracy: 0.8680
# Epoch 10/30
# 860/860 [==============================] - 31s 36ms/step - loss: 0.3365 - accuracy: 0.8786 - val_loss: 0.3863 - val_accuracy: 0.8582
# Epoch 11/30
# 860/860 [==============================] - 33s 39ms/step - loss: 0.3242 - accuracy: 0.8824 - val_loss: 0.3454 - val_accuracy: 0.8748
# Epoch 12/30
# 860/860 [==============================] - 32s 38ms/step - loss: 0.3132 - accuracy: 0.8862 - val_loss: 0.3227 - val_accuracy: 0.8872
# Epoch 13/30
# 860/860 [==============================] - 32s 37ms/step - loss: 0.3060 - accuracy: 0.8889 - val_loss: 0.3289 - val_accuracy: 0.8882
# Epoch 14/30
# 860/860 [==============================] - 31s 37ms/step - loss: 0.2975 - accuracy: 0.8913 - val_loss: 0.3984 - val_accuracy: 0.8508
# Epoch 15/30
# 860/860 [==============================] - 30s 35ms/step - loss: 0.2895 - accuracy: 0.8951 - val_loss: 0.3814 - val_accuracy: 0.8634
# Epoch 16/30
# 860/860 [==============================] - 30s 35ms/step - loss: 0.2830 - accuracy: 0.8973 - val_loss: 0.2956 - val_accuracy: 0.8956
# Epoch 17/30
# 860/860 [==============================] - 28s 33ms/step - loss: 0.2756 - accuracy: 0.8999 - val_loss: 0.3999 - val_accuracy: 0.8616
# Epoch 18/30
# 860/860 [==============================] - 32s 37ms/step - loss: 0.2699 - accuracy: 0.9013 - val_loss: 0.3522 - val_accuracy: 0.8746
# Epoch 19/30
# 860/860 [==============================] - 31s 37ms/step - loss: 0.2640 - accuracy: 0.9034 - val_loss: 0.3024 - val_accuracy: 0.8918
# Epoch 20/30
# 860/860 [==============================] - 33s 38ms/step - loss: 0.2584 - accuracy: 0.9054 - val_loss: 0.3197 - val_accuracy: 0.8854
# Epoch 21/30
# 860/860 [==============================] - 33s 38ms/step - loss: 0.2525 - accuracy: 0.9085 - val_loss: 0.2815 - val_accuracy: 0.9004
# Epoch 22/30
# 860/860 [==============================] - 37s 42ms/step - loss: 0.2471 - accuracy: 0.9098 - val_loss: 0.2819 - val_accuracy: 0.8980
# Epoch 23/30
# 860/860 [==============================] - 28s 33ms/step - loss: 0.2419 - accuracy: 0.9106 - val_loss: 0.2795 - val_accuracy: 0.9036
# Epoch 24/30
# 860/860 [==============================] - 28s 32ms/step - loss: 0.2371 - accuracy: 0.9134 - val_loss: 0.2990 - val_accuracy: 0.8904
# Epoch 25/30
# 860/860 [==============================] - 28s 33ms/step - loss: 0.2325 - accuracy: 0.9153 - val_loss: 0.2872 - val_accuracy: 0.8980
# Epoch 26/30
# 860/860 [==============================] - 29s 34ms/step - loss: 0.2288 - accuracy: 0.9160 - val_loss: 0.2791 - val_accuracy: 0.9032
# Epoch 27/30
# 860/860 [==============================] - 27s 32ms/step - loss: 0.2243 - accuracy: 0.9184 - val_loss: 0.2699 - val_accuracy: 0.9032
# Epoch 28/30
# 860/860 [==============================] - 28s 32ms/step - loss: 0.2199 - accuracy: 0.9189 - val_loss: 0.3023 - val_accuracy: 0.8932
# Epoch 29/30
# 860/860 [==============================] - 27s 32ms/step - loss: 0.2147 - accuracy: 0.9213 - val_loss: 0.2696 - val_accuracy: 0.9024
# Epoch 30/30
# 860/860 [==============================] - 28s 32ms/step - loss: 0.2121 - accuracy: 0.9218 - val_loss: 0.2709 - val_accuracy: 0.9048

# %%
import pandas as pd

pd.DataFrame(model_history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
ev = model.evaluate(X_test_n, y_test)
# Out:
# 313/313 [==============================] - 2s 8ms/step - loss: 0.2821 - accuracy: 0.8997

# %%
ev
# Out:
# [0.2820536494255066, 0.8996999859809875]

# %%
X_new = X_test[:3]

# %%
y_pred = model.predict_classes(X_new)
y_pred
# Out:
# C:\Python39\lib\site-packages\tensorflow\python\keras\engine\sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
# array([9, 2, 1], dtype=int64)

# %%
y_test[:3]
# Out:
# array([9, 2, 1], dtype=uint8)

# %%
print(plt.imshow(X_test[0].reshape((28,28))))
# Out:
# AxesImage(54,36;334.8x217.44)

# %%
keras.backend.clear_session
# Out:
# <function tensorflow.python.keras.backend.clear_session()>

# %%
del model

# %% [markdown]
# ### Pooling vs No Pooling

# %%
model_a = keras.models.Sequential()
model_a.add(keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides=1, padding='valid', activation='relu', input_shape=(28, 28, 1)))
model_a.add(keras.layers.MaxPooling2D((2, 2)))
model_a.add(keras.layers.Flatten())
model_a.add(keras.layers.Dense(300, activation="relu"))
model_a.add(keras.layers.Dense(100, activation="relu"))
model_a.add(keras.layers.Dense(10, activation="softmax"))

model_b = keras.models.Sequential()
model_b.add(keras.layers.Conv2D(filters = 32, kernel_size = (3, 3), strides=1, padding='valid', activation='relu', input_shape=(28, 28, 1)))
model_b.add(keras.layers.Flatten())
model_b.add(keras.layers.Dense(300, activation="relu"))
model_b.add(keras.layers.Dense(100, activation="relu"))
model_b.add(keras.layers.Dense(10, activation="softmax"))

# %%
model_a.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 5408)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 300)               1622700
# _________________________________________________________________
# dense_4 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 1,654,130
# Trainable params: 1,654,130
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_b.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 21632)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 300)               6489900
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 6,521,330
# Trainable params: 6,521,330
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_a.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

model_b.compile(loss="sparse_categorical_crossentropy",
              optimizer="sgd",
              metrics=["accuracy"])

# %%
model_history_a = model_a.fit(X_train, y_train, epochs=3,batch_size= 64,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/3
# 860/860 [==============================] - 30s 34ms/step - loss: 0.8466 - accuracy: 0.7083 - val_loss: 0.7893 - val_accuracy: 0.7126
# Epoch 2/3
# 860/860 [==============================] - 29s 34ms/step - loss: 0.5359 - accuracy: 0.8062 - val_loss: 0.4955 - val_accuracy: 0.8084
# Epoch 3/3
# 860/860 [==============================] - 30s 34ms/step - loss: 0.4792 - accuracy: 0.8267 - val_loss: 0.9630 - val_accuracy: 0.6964

# %%
model_history_b = model_b.fit(X_train, y_train, epochs=3,batch_size= 64,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/3
# 860/860 [==============================] - 64s 73ms/step - loss: 0.7399 - accuracy: 0.7450 - val_loss: 0.6992 - val_accuracy: 0.7568
# Epoch 2/3
# 860/860 [==============================] - 62s 72ms/step - loss: 0.4949 - accuracy: 0.8218 - val_loss: 0.4726 - val_accuracy: 0.8182
# Epoch 3/3
# 860/860 [==============================] - 62s 72ms/step - loss: 0.4432 - accuracy: 0.8391 - val_loss: 1.0101 - val_accuracy: 0.6910

# %% [markdown]
# The second model has a slightly better accuracy because it does not have the pooling layer which actually results in a bit of data loss. Although it saves a lot of computational time, but it also decreases a little accuracy.
# Not much, only a little.
